# %% [markdown]
# # Load Libraries / Import Datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt

from geopy.distance import geodesic
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures

pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv('../datasets/train.csv')
test = pd.read_csv('../datasets/test.csv')
spray = pd.read_csv('../datasets/spray.csv')
weather = pd.read_csv('../datasets/weather.csv')

# %% [markdown]
# # Train dataset

# %%
train.dtypes
# Out:
# Date                       object
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# NumMosquitos                int64
# WnvPresent                  int64
# dtype: object

# %%
todatetime(train)

# %%
train.shape
# Out:
# (10506, 12)

# %%
train.isnull().sum()
# Out:
# Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# NumMosquitos              0
# WnvPresent                0
# dtype: int64

# %%
train.duplicated(keep=False).sum()
# Out:
# 1062

# %%
train.loc[train.duplicated(),:].shape
# Out:
# (813, 12)

# %%
#these are probably duped entries (1 mosquito)

train.loc[(train.duplicated(keep=False)) & (train['NumMosquitos'] == 1),:]
# Out:
#            Date                                            Address  \
# 98   2007-06-26     2200 West 113th Street, Chicago, IL 60643, USA
# 99   2007-06-26     2200 West 113th Street, Chicago, IL 60643, USA
# 511  2007-07-18  3300 West Randolph Street, Chicago, IL 60612, USA
# 512  2007-07-18  3300 West Randolph Street, Chicago, IL 60612, USA
# 818  2007-08-01     2200 West 113th Street, Chicago, IL 60643, USA
# ...         ...                                                ...
# 7324 2011-08-12  ORD Terminal 5, O'Hare International Airport, ...
# 7790 2011-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 7793 2011-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 7799 2011-09-12            Ohare Court, Bensenville, IL 60106, USA
# 7800 2011-09-12            Ohare Court, Bensenville, IL 60106, USA
#
#                      Species  Block            Street  Trap  \
# 98    CULEX PIPIENS/RESTUANS     22        W 113TH ST  T086
# 99    CULEX PIPIENS/RESTUANS     22        W 113TH ST  T086
# 511           CULEX RESTUANS     33     E RANDOLPH ST  T044
# 512           CULEX RESTUANS     33     E RANDOLPH ST  T044
# 818           CULEX RESTUANS     22        W 113TH ST  T086
# ...                      ...    ...               ...   ...
# 7324        CULEX SALINARIUS     10   W OHARE AIRPORT  T900
# 7790          CULEX RESTUANS     10   W OHARE AIRPORT  T900
# 7793          CULEX RESTUANS     10   W OHARE AIRPORT  T900
# 7799           CULEX PIPIENS     10           W OHARE  T903
# 7800           CULEX PIPIENS     10           W OHARE  T903
#
#                   AddressNumberAndStreet   Latitude  Longitude  \
# 98         2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 99         2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 511     3300  E RANDOLPH ST, Chicago, IL  41.883284 -87.705085
# 512     3300  E RANDOLPH ST, Chicago, IL  41.883284 -87.705085
# 818        2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# ...                                  ...        ...        ...
# 7324  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 7790  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 7793  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 7799          1000  W OHARE, Chicago, IL  41.957799 -87.930995
# 7800          1000  W OHARE, Chicago, IL  41.957799 -87.930995
#
#       AddressAccuracy  NumMosquitos  WnvPresent
# 98                  8             1           0
# 99                  8             1           0
# 511                 8             1           0
# 512                 8             1           0
# 818                 8             1           0
# ...               ...           ...         ...
# 7324                9             1           0
# 7790                9             1           0
# 7793                9             1           0
# 7799                5             1           0
# 7800                5             1           0
#
# [90 rows x 12 columns]

# %%
train = train.loc[~((train.duplicated()) & (train['NumMosquitos'] == 1)),:]

# %%
#remaning dupes = when trap has >50, new row added 
#(from data dict: These test results are organized in such a way that when the number of mosquitos exceed 50, they are split into another record (another row in the dataset), such that the number of mosquitos are capped at 50.)

train.loc[train.duplicated(keep=False),:]
# Out:
#             Date                                            Address  \
# 293   2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 295   2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 350   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 351   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 353   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# ...          ...                                                ...
# 10124 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 10259 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10262 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10391 2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 10392 2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
#
#                       Species  Block            Street  Trap  \
# 293    CULEX PIPIENS/RESTUANS     22        W 113TH ST  T086
# 295    CULEX PIPIENS/RESTUANS     22        W 113TH ST  T086
# 350    CULEX PIPIENS/RESTUANS     35        W 116TH ST  T158
# 351    CULEX PIPIENS/RESTUANS     35        W 116TH ST  T158
# 353    CULEX PIPIENS/RESTUANS     35        W 116TH ST  T158
# ...                       ...    ...               ...   ...
# 10124  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 10259  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 10262  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 10391           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 10392           CULEX PIPIENS     10   W OHARE AIRPORT  T900
#
#                    AddressNumberAndStreet   Latitude  Longitude  \
# 293         2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 295         2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 350         3500  W 116TH ST, Chicago, IL  41.682587 -87.707973
# 351         3500  W 116TH ST, Chicago, IL  41.682587 -87.707973
# 353         3500  W 116TH ST, Chicago, IL  41.682587 -87.707973
# ...                                   ...        ...        ...
# 10124  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10259  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10262  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10391  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10392  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
#
#        AddressAccuracy  NumMosquitos  WnvPresent
# 293                  8            50           0
# 295                  8            50           0
# 350                  9            50           0
# 351                  9            50           0
# 353                  9            50           0
# ...                ...           ...         ...
# 10124                9            50           1
# 10259                9            50           0
# 10262                9            50           0
# 10391                9            13           0
# 10392                9            13           0
#
# [972 rows x 12 columns]

# %%
train = train.groupby([col for col in train.columns if col not in ['NumMosquitos', 'WnvPresent']]).sum().sort_values(by='WnvPresent')
train.reset_index(inplace=True)

# %%
train.shape
# Out:
# (8475, 12)

# %%
#Return those summed 'WnvPresent' values to 1 

train['WnvPresent'] = train['WnvPresent'].map(lambda x : 1 if x > 0 else x)

# %%
train['WnvPresent'].value_counts()
# Out:
# 0    8018
# 1     457
# Name: WnvPresent, dtype: int64

# %%
train
# Out:
#            Date                                            Address  \
# 0    2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 1    2011-07-29  7000 West Armitage Avenue, Chicago, IL 60707, USA
# 2    2011-07-29  7000 West Armitage Avenue, Chicago, IL 60707, USA
# 3    2011-07-29  7000 North Moselle Avenue, Chicago, IL 60646, USA
# 4    2011-07-29  7000 North Moselle Avenue, Chicago, IL 60646, USA
# ...         ...                                                ...
# 8470 2007-08-22        South Stony Island Avenue, Chicago, IL, USA
# 8471 2007-08-22                South Doty Avenue, Chicago, IL, USA
# 8472 2013-08-29  ORD Terminal 5, O'Hare International Airport, ...
# 8473 2013-08-01  ORD Terminal 5, O'Hare International Airport, ...
# 8474 2007-08-16                South Doty Avenue, Chicago, IL, USA
#
#                      Species  Block               Street  Trap  \
# 0     CULEX PIPIENS/RESTUANS     11          W ROOSEVELT  T048
# 1     CULEX PIPIENS/RESTUANS     70    W ARMITAGE AVENUE  T151
# 2              CULEX PIPIENS     70    W ARMITAGE AVENUE  T151
# 3             CULEX RESTUANS     70         N MOSELL AVE  T008
# 4     CULEX PIPIENS/RESTUANS     70         N MOSELL AVE  T008
# ...                      ...    ...                  ...   ...
# 8470           CULEX PIPIENS     10   S STONY ISLAND AVE  T138
# 8471           CULEX PIPIENS     12           S DOTY AVE  T115
# 8472           CULEX PIPIENS     10      W OHARE AIRPORT  T900
# 8473  CULEX PIPIENS/RESTUANS     10      W OHARE AIRPORT  T900
# 8474           CULEX PIPIENS     12           S DOTY AVE  T115
#
#                      AddressNumberAndStreet   Latitude  Longitude  \
# 0            1100  W ROOSEVELT, Chicago, IL  41.867108 -87.654224
# 1     7000   W ARMITAGE AVENUE, Chicago, IL  41.916265 -87.800515
# 2     7000   W ARMITAGE AVENUE, Chicago, IL  41.916265 -87.800515
# 3           7000  N MOSELL AVE, Chicago, IL  42.008314 -87.777921
# 4           7000  N MOSELL AVE, Chicago, IL  42.008314 -87.777921
# ...                                     ...        ...        ...
# 8470  1000  S STONY ISLAND AVE, Chicago, IL  41.726465 -87.585413
# 8471          1200  S DOTY AVE, Chicago, IL  41.673408 -87.599862
# 8472     1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 8473     1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 8474          1200  S DOTY AVE, Chicago, IL  41.673408 -87.599862
#
#       AddressAccuracy  NumMosquitos  WnvPresent
# 0                   8             1           0
# 1                   8           147           0
# 2                   8             1           0
# 3                   9             2           0
# 4                   9             3           0
# ...               ...           ...         ...
# 8470                5          1054           1
# 8471                5          1554           1
# 8472                9           281           1
# 8473                9           984           1
# 8474                5          2532           1
#
# [8475 rows x 12 columns]

# %%
# Out:
# 0       2007
# 1       2011
# 2       2011
# 3       2011
# 4       2011
#         ...
# 8470    2007
# 8471    2007
# 8472    2013
# 8473    2013
# 8474    2007
# Name: Date, Length: 8475, dtype: period[A-DEC]

# %%
train['year'] = train['Date'].dt.year
train['month'] = train['Date'].dt.month

# %%
# train['year'] = pd.to_datetime(train['Date']).dt.to_period('Y')
# train['month'] = pd.to_datetime(train['Date']).dt.to_period('Y')

# %%
train['month'].value_counts()
# Out:
# 8     2750
# 7     2096
# 9     1947
# 6     1337
# 10     264
# 5       81
# Name: month, dtype: int64

# %%
train['year'].value_counts()
# Out:
# 2007    2775
# 2013    2012
# 2009    1915
# 2011    1773
# Name: year, dtype: int64
